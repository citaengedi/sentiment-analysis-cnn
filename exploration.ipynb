# %%
import pandas as pd
import numpy as np

# %%
data_type = {"negatif": np.float64, "netral": np.float64, "positif": np.float64}
#data_type = {"senang": np.float64, "sedih": np.float64, "kecewa": np.float64, "bingung": np.float64, "cinta": np.float64}
#data_type = {"ekonomi": np.float64, "fisik_tampilan": np.float64, "emosi": np.float64, "ekonomi": np.float64, "performa": np.float64}

# %%
#File ORI sebelum data balancing lalalala
data = pd.read_csv('drive/MyDrive/TA/newera/datatrain.csv', dtype=data_type)
#File SENTIMEN SETELAh data balancing
#data = pd.read_csv('drive/MyDrive/TA/ovrs 2.csv', dtype=data_type)
#File ASPEK SETELAH data balancing
#data = pd.read_csv('drive/MyDrive/TA/900.csv', dtype=data_type)
data = data.dropna()
#data = data.drop_duplicates(subset='Comment', keep='first', inplace=False, ignore_index=False)
data
# Out:
#       Unnamed: 0  ...     aspek
# 0            346  ...  performa
# 1           1482  ...  performa
# 2           2563  ...     emosi
# 3            163  ...     emosi
# 4           1490  ...  performa
# ...          ...  ...       ...
# 2614        1646  ...   ekonomi
# 2615        1859  ...     emosi
# 2616        1279  ...     emosi
# 2617        1250  ...   ekonomi
# 2618        2205  ...  performa
#
# [2618 rows x 12 columns]

# %% [markdown]
# **Jumlah Data (emosi)**

# %%
#label = ['negatif', 'netral', 'positif']
#label = ['bingung', 'cinta', 'kecewa', 'sedih', 'senang']
label = ['ekonomi', 'emosi', 'fisik_tampilan', 'layanan', 'performa']

# %%
label_counts = pd.DataFrame({"labels":label, "count":data[label].sum()})

# %%
label_counts
# Out:
#                         labels  count
# ekonomi                ekonomi    336
# emosi                    emosi   1031
# fisik_tampilan  fisik_tampilan    244
# layanan                layanan     90
# performa              performa    917

# %%
import seaborn as sns
from pylab import rcParams

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 7, 5

sns.barplot(x="labels", y="count", data=label_counts)

# %% [markdown]
# **Jumlah Data Sentimen**

# %%
data1_type = {"senang": np.float64, "sedih": np.float64, "kecewa": np.float64, "bingung": np.float64, "cinta": np.float64}
data1 = pd.read_csv('drive/MyDrive/TA/emosi.csv', dtype=data1_type)
data1 = data1.dropna()
data1
# Out:
#                                                 Comment  sedih  ...  cinta  bingung
# 0                   kalau harga bukan pertimbangan beli    0.0  ...    0.0      1.0
# 1                                             inshallah    0.0  ...    0.0      0.0
# 2                                 smsg ungu kok lucu si    0.0  ...    0.0      0.0
# 3     tukar tambah aja percuma begini ga bisa dihara...    0.0  ...    0.0      0.0
# 4                                ini bukan sih lucu bgt    0.0  ...    0.0      0.0
# ...                                                 ...    ...  ...    ...      ...
# 3035  fitur superdart 8 saya tidak berfungsi saya su...    0.0  ...    0.0      0.0
# 3036            mamaku juga klo gk pake kamera ig jelek    1.0  ...    0.0      0.0
# 3037  c15 batre nya awet bgt asal ga dimainin pas la...    0.0  ...    0.0      0.0
# 3038      pakai ga sampe setahun banyak masalah baterai    0.0  ...    0.0      0.0
# ...

# %%
#label_sen = ['negatif', 'netral', 'positif']
label_sen = ["senang", "sedih", "kecewa", "bingung", "cinta"]

# %%
label_sen_count = pd.DataFrame({"labels":label_sen, "count":data1[label_sen].sum()})

# %%
label_sen_count
# Out:
#           labels  count
# senang    senang  785.0
# sedih      sedih  419.0
# kecewa    kecewa  417.0
# bingung  bingung  734.0
# cinta      cinta  625.0

# %%
import seaborn as sns
from pylab import rcParams

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 6, 4

sns.barplot(x="labels", y="count", data=label_sen_count)

# %% [markdown]
# **Jumlah Data Aspek**

# %%
label_aspek = ['ekonomi', 'emosi','performa', 'fisik_tampilan', 'layanan pelanggan']

# %%
label_aspek_count = pd.DataFrame({"labels":label_aspek, "count":data1[label_aspek].sum()})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-b15fa00dc164> in <module>()
# ----> 1 label_aspek_count = pd.DataFrame({"labels":label_aspek, "count":data1[label_aspek].sum()})
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...

# %%
label_aspek_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-792088b06383> in <module>()
# ----> 1 label_aspek_count
#
# NameError: name 'label_aspek_count' is not defined

# %%
import seaborn as sns
from pylab import rcParams

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8

sns.barplot(x="labels", y="count", data=label_aspek_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-28fdba3c3656> in <module>()
#      10 rcParams['figure.figsize'] = 12, 8
#      11
# ---> 12 sns.barplot(x="labels", y="count", data=label_aspek_count)
#
# NameError: name 'label_aspek_count' is not defined

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
string = pd.Series(data1['Comment']).str.cat(sep=' ')
string
# Out:
# 'kalau harga bukan pertimbangan beli inshallah smsg ungu kok lucu si tukar tambah aja percuma begini ga bisa diharapkandaripada makin sakit hati ini bukan sih lucu bgt paling aman dari segi spek dan juga layanan after sales kalau mau 4 jutaan bnyk pilihannya bisa juga coba harganya justru under 4 juta kalau 4 jutaan artinya mid range skrg bnyk bagus mid rangenya bisa coba atau bang punya lebjh banyak fitur aja barangnya awet baterainya juga engga gampang bocor coba aja tuhyang baru launching tanyarl punya sama ayo review nyaa kalau bisa milih mending deh kalau buat skrg banyak worth bgt buat dibeli bisa coba a seriesnya terbaru atau bisa juga m seriesrata2 badak2 bgt hapenya galaxy tampil dengan desain kamera contour cut mutss ada pake atau gakkxx cm worth it ga ya beli sumsang buat keperluan kuliah sama foto2 objek kalo kuliah lapangan gemes bgt ada warna ungu baru saja merilis jajaran dari galaxy a series salah satunya adalah galaxy mesisan ae selisihnya udah jauh bgtt tp kalau mau
# ...

# %%
sw = ['redmi','nder','note','vivo','yg','di','asus','zenfone','hp','poco','aku','pro','m12',
      'y20','c25','a15','yang','ip','realme','xiaomi','infinix','10','a32','a52','a72', 'a31',
      'm3','samsung','ip','a51',',','oppo','9t','oneplus','sih','dan','juga','banget','bgt',
      'itu','masih','udah','gak','kalo','atau','gw','apa','nya','ya','tapi','ini','iphone','xs',
      'untuk','aja','bisa','ada','dengan','dah','tp','galaxy','xr','si','udh','ga','mana','gue',
      'klo','jg','gitu','ku','dulu','emang','lah','dari', 'f3','x60','ni','x3','huhu','pada','lagi','jadi', 'gua','cuma','dong','kalau','soalnya'
      , 'kan','tau','pa','mah','nih','kok','saya','sama','buat','lebih','dia','bismillah','kak','pake','max','pakai','lama','pas','wkwk','karena'
      ,'tuh','yaa','ke']

# %%
wordcloud = WordCloud(width=300, stopwords=sw,height=150,max_font_size=30,max_words=1000,collocations=False, background_color='white').generate(string)
plt.figure(figsize=(10,9))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
