# %%
import pandas as pd

# %%
data = pd.read_csv('drive/MyDrive/TA/newfix.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
train, val= train_test_split(data, test_size=0.1, random_state =125)
val.head(400)
# Out:
#                                                 Comment  ...           aspek
# 2214  kejar kamera kalau jenis gaming kalau tak kisa...  ...        performa
# 300   lagi nyari warna ungu trus tetiba keinget kalo...  ...  fisik_tampilan
# 927   udah pernah pake soalnya kurleb 5 tahun jadi g...  ...           emosi
# 1265                         semakin depan bismillah f3  ...           emosi
# 1406  5 sebab mengapa f3 5g antara peranti terbaik p...  ...        performa
# ...                                                 ...  ...             ...
# 1368                       bingung mending x3 atau huft  ...           emosi
# 1235  iyak ni seri nya dari deh keknya tapi emang sp...  ...         ekonomi
# 2541                        sepupu ku pake 11 bagus kok  ...        performa
# 2202  ada pakai max dah update ke 146 and kamera dep...  ...        performa
# 1046                            semoga dapat hadiah ini  ...           emosi
#
# [292 rows x 11 columns]

# %%
pd.DataFrame(val).to_csv("drive/MyDrive/TA/newdataval.csv", index=True)
pd.DataFrame(train).to_csv("drive/MyDrive/TA/newera/datatrain.csv", index=True)
